# %%
this_list = [0,1,2,3,4]

# %%
this_list.append(5)

# %%
this_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
this_list.pop()
# Out:
# 5

# %%
this_list
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# this_list.insert. use SHIFT + TAB to display all the available methods for this object

# %%
help(this_list.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %% [markdown]
# ###### Third option to get information about things:

# %% [markdown]
# Python 3.10.5 documentation https://docs.python.org/3/

# %% [markdown]
# ![2022-06-24_14-23-37.png](attachment:2022-06-24_14-23-37.png)

# %% [markdown]
# ![2022-06-24_14-25-17.png](attachment:2022-06-24_14-25-17.png)

# %% [markdown]
# ![2022-06-24_14-26-19.png](attachment:2022-06-24_14-26-19.png)

# %% [markdown]
# ![2022-06-24_14-27-27.png](attachment:2022-06-24_14-27-27.png)
